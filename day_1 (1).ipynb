# %%
a=5
b=10.5
c='venki'
d=5
e=complex(a,b)
print(e.real)
if (a==d):
  print("true")
elif(a<b):
  print("b is greater than a")
else:
  print("false")

# %%
print(type(a))

# %%
for i in range (1,5):
  print(i)

# %%
i=1
while i < 6:
  print(i)
  i+=1

# %%
class grandfather:
  def __init__(self,a,b):
    self.a=a
    self.b=b
p1 = grandfather("sai",21)
print(p1.a)
print(p1.b)

# %%
#list
list =[1,2,3,4,5,6]
list

# %%
print(type(list))

# %%
print(len(list))

# %%
print(list[2])

# %%
print(list[0:6])

# %%
print(list[-2])

# %%
tuple=(1,2,3,4,5,6)
print(tuple[1:5])

# %%
print(type(tuple))

# %%
set={1,2,3,4}
print(type(set))

# %%
set1={2,5,6}
c = set.union(set1)
print(c)
