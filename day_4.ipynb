# %%
import pandas as pd
import numpy as np
d ={'a':[1,np.nan,2],'b':[3,np.nan,np.nan],'c':[1,2,6]
     }
df = pd.DataFrame(d)
df
# Out:
#      a    b  c
# 0  1.0  3.0  1
# 1  NaN  NaN  2
# 2  2.0  NaN  6

# %%
df.dropna()
# Out:
#      a    b  c
# 0  1.0  3.0  1

# %%
df.dropna(axis=1)
# Out:
#    c
# 0  1
# 1  2
# 2  6

# %%
df
# Out:
#      a    b  c
# 0  1.0  3.0  1
# 1  NaN  NaN  2
# 2  2.0  NaN  6

# %%
df.fillna(value='fill value')
# Out:
#             a           b  c
# 0         1.0         3.0  1
# 1  fill value  fill value  2
# 2         2.0  fill value  6

# %%
df=pd.DataFrame(d)

# %%
a=df['a'].fillna(value = df['a'].mean())
a
# Out:
# 0    1.0
# 1    1.5
# 2    2.0
# Name: a, dtype: float64

# %%
data={
    'company':['BMW',911,'f29','benz','BMW'],
    'owner':['sai','hari','venki','sailesh','haril'],
    'sales':[200,567,334,556,677]
}
df = pd.DataFrame(data)

# %%
df
# Out:
#   company    owner  sales
# 0     BMW      sai    200
# 1     911     hari    567
# 2     f29    venki    334
# 3    benz  sailesh    556
# 4     BMW    haril    677

# %%
comp =df.groupby('company')
comp

# %%
comp.mean(numeric_only=True)
# Out:
#          sales
# company
# 911      567.0
# BMW      438.5
# benz     556.0
# f29      334.0

# %%
comp.sum()
# Out:
#             owner  sales
# company
# 911          hari    567
# BMW      saiharil    877
# benz      sailesh    556
# f29         venki    334

# %%
comp['sales'].std()
# Out:
# company
# 911            NaN
# BMW     337.289935
# benz           NaN
# f29            NaN
# Name: sales, dtype: float64

# %%
df.groupby('company').count()
# Out:
#          owner  sales
# company
# 911          1      1
# BMW          2      2
# benz         1      1
# f29          1      1

# %%
df.groupby('company').describe()
# Out:
#         sales
#         count   mean         std    min     25%    50%     75%    max
# company
# 911       1.0  567.0         NaN  567.0  567.00  567.0  567.00  567.0
# BMW       2.0  438.5  337.289935  200.0  319.25  438.5  557.75  677.0
# benz      1.0  556.0         NaN  556.0  556.00  556.0  556.00  556.0
# f29       1.0  334.0         NaN  334.0  334.00  334.0  334.00  334.0
