# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# from google.colab import files
# uploaded=files.upload()

# %%
df= pd.read_csv("/content/Student Degree College Data.csv")

# %%
df.isnull()
# Out:
#       form_no   name  category  minority  gender  hs_total  hs_pass_year  \
# 0       False  False     False     False   False     False         False
# 1       False  False     False     False   False     False         False
# 2       False  False     False     False   False     False         False
# 3       False  False     False     False   False     False         False
# 4       False  False     False     False   False     False         False
# ...       ...    ...       ...       ...     ...       ...           ...
# 5138    False  False     False     False   False     False         False
# 5139    False  False     False     False   False     False         False
# 5140    False  False     False     False   False     False         False
# 5141    False  False     False     False   False     False         False
# 5142    False  False     False     False   False     False         False
#
#       first_choice_sub  first_choice_marks  second_choice_sub  \
# 0                False               False              False
# 1                False               False              False
# 2                False               False              False
# 3                 True               False               True
# 4                 True               False               True
# ...                ...                 ...                ...
# 5138              True               False               True
# 5139              True               False               True
# 5140              True               False               True
# 5141              True               False               True
# 5142             False               False              False
#
#       second_choice_marks  first_choice_stream  second_choice_stream
# 0                   False                False                 False
# 1                   False                False                 False
# 2                   False                False                 False
# 3                   False                False                 False
# 4                   False                False                 False
# ...                   ...                  ...                   ...
# 5138                False                False                 False
# 5139                False                False                 False
# 5140                False                False                 False
# 5141                False                False                 False
# 5142                False                False                 False
#
# [5143 rows x 13 columns]

# %%
df.dropna()
# Out:
#       form_no                  name category minority gender  hs_total  \
# 0     1801371       Susmita Bhowmik       UR       NO      F       381
# 1     1803096             Ankur Das       SC       NO      M       262
# 2     1801287        Rashmita Tanti       UR       NO      M       278
# 7     1801105   Snehabrata Dasgupta       UR       NO      M       327
# 8     1800886      Bijan Sankar Das       SC       NO      M       363
# ...       ...                   ...      ...      ...    ...       ...
# 5056  1824153     Mesak Lalmuanfela       ST       NO      M       298
# 5057  1824486     Ratul Chakraborty       UR       NO      M       415
# 5058  1812856            Rahul Paul       UR       NO      M       373
# 5059  1822484  Sutapa Modak Bhowmik       UR       NO      F       337
# 5142      501         Jayatri Datta       UR       NO      F       368
#
#       hs_pass_year  first_choice_sub  first_choice_marks second_choice_sub  \
# 0             2018       Mathematics                  80       Mathematics
# 1             2018         Education                  61           Bengali
# 2             2018  Human Physiology                  74            Botany
# 7             2018         Chemistry                  78           Zoology
# 8             2018           Physics                  80         Chemistry
# ...            ...               ...                 ...               ...
# 5056          2016           English                  74           English
# 5057          2018           Physics                  85           Physics
# 5058          2018  Human Physiology                  84            Botany
# 5059          2018           Zoology                  56           Zoology
# 5142          2018         Sociology                  86         Sociology
#
#       second_choice_marks first_choice_stream second_choice_stream
# 0                      80    Physical Science     Physical Science
# 1                      58                Arts                 Arts
# 2                      74         Bio Science          Bio Science
# 7                      78    Physical Science          Bio Science
# 8                      74    Physical Science     Physical Science
# ...                   ...                 ...                  ...
# 5056                   74                Arts                 Arts
# 5057                   85    Physical Science     Physical Science
# 5058                   84         Bio Science     Physical Science
# 5059                   56         Bio Science          Bio Science
# 5142                   86                Arts                 Arts
#
# [3602 rows x 13 columns]

# %%
df.head()
# Out:
#    form_no             name category minority gender  hs_total  hs_pass_year  \
# 0  1801371  Susmita Bhowmik       UR       NO      F       381          2018
# 1  1803096        Ankur Das       SC       NO      M       262          2018
# 2  1801287   Rashmita Tanti       UR       NO      M       278          2018
# 3  1803173     Sanjib Ghosh       UR       NO      M       194          2018
# 4  1801077      Swarupa Pal       UR       NO      F       320          2015
#
#    first_choice_sub  first_choice_marks second_choice_sub  \
# 0       Mathematics                  80       Mathematics
# 1         Education                  61           Bengali
# 2  Human Physiology                  74            Botany
# 3               NaN                   0               NaN
# 4               NaN                   0               NaN
#
#    second_choice_marks first_choice_stream second_choice_stream
# 0                   80    Physical Science     Physical Science
# 1                   58                Arts                 Arts
# 2                   74         Bio Science          Bio Science
# 3                    0                Arts                 Arts
# 4                    0         Bio Science          Bio Science

# %%
df.tail()
# Out:
#       form_no                name category minority gender  hs_total  \
# 5138      301        Alamgir Miah       UR   Muslim      M       190
# 5139      302          Manir Miah       UR   Muslim      M       201
# 5140      303  Subhankar Majumder       UR       NO      M       294
# 5141      401      Utpal Majumder       UR       NO      M       193
# 5142      501       Jayatri Datta       UR       NO      F       368
#
#       hs_pass_year first_choice_sub  first_choice_marks second_choice_sub  \
# 5138          2018              NaN                   0               NaN
# 5139          2018              NaN                   0               NaN
# 5140          2018              NaN                   0               NaN
# 5141          2018              NaN                   0               NaN
# 5142          2018        Sociology                  86         Sociology
#
#       second_choice_marks first_choice_stream second_choice_stream
# 5138                    0                Arts                 Arts
# 5139                    0                Arts                 Arts
# 5140                    0                Arts                 Arts
# 5141                    0                Arts                 Arts
# 5142                   86                Arts                 Arts

# %%
df.describe()
# Out:
#             form_no     hs_total  hs_pass_year  first_choice_marks  \
# count  5.143000e+03  5143.000000   5143.000000         5143.000000
# mean   1.779779e+06   281.294770   2017.911141           46.243243
# std    2.280340e+05    65.827077      0.445469           32.493253
# min    1.000000e+00   150.000000   2009.000000            0.000000
# 25%    1.803600e+06   228.000000   2018.000000            0.000000
# 50%    1.807443e+06   277.000000   2018.000000           58.000000
# 75%    1.813434e+06   328.000000   2018.000000           71.000000
# max    1.824613e+06   479.000000   2018.000000          100.000000
#
#        second_choice_marks
# count          5143.000000
# mean             45.759479
# std              32.314099
# min               0.000000
# 25%               0.000000
# 50%              57.000000
# 75%              71.000000
# max             100.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5143 entries, 0 to 5142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   form_no               5143 non-null   int64
#  1   name                  5143 non-null   object
#  2   category              5143 non-null   object
#  3   minority              5143 non-null   object
#  4   gender                5143 non-null   object
#  5   hs_total              5143 non-null   int64
#  6   hs_pass_year          5143 non-null   int64
#  7   first_choice_sub      3602 non-null   object
#  8   first_choice_marks    5143 non-null   int64
#  9   second_choice_sub     3602 non-null   object
#  10  second_choice_marks   5143 non-null   int64
#  11  first_choice_stream   5143 non-null   object
#  12  second_choice_stream  5143 non-null   object
# dtypes: int64(5), object(8)
# memory usage: 522.5+ KB

# %%
aa=df['category'].unique()
aa
# Out:
# array(['UR', 'SC', 'ST'], dtype=object)

# %%
s = df['first_choice_marks']

# %%
a = df[ 'second_choice_marks']

# %%
sns.scatterplot(s)
# Out:
# <Axes: ylabel='first_choice_marks'>

# %%
x = df.Sales
x
# Out:
# 0       261.9600
# 1       731.9400
# 2        14.6200
# 3       957.5775
# 4        22.3680
#           ...
# 9795      3.7980
# 9796     10.3680
# 9797    235.1880
# 9798     26.3760
# 9799     10.3840
# Name: Sales, Length: 9800, dtype: float64

# %%
import seaborn as sns
sns.distplot(x)
# Out:
# <ipython-input-85-508099808626>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x)
# <Axes: xlabel='Sales', ylabel='Density'>

# %%
sns.histplot(s)
##plt.xticks(rotation=45)
# Out:
# <Axes: xlabel='first_choice_marks', ylabel='Count'>

# %%
f=df.gender
g=df.category
plt.plot(f,g)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
