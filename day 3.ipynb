# %%
import numpy as np
arr1=np.array(([5,4],[6,4]),dtype=int)
arr2=np.array(([2,3],[1,3]),dtype=int)
Sum=np.add(arr1,arr2)
print(Sum)
# Out:
# [[7 7]
#  [7 7]]

# %%
Sum1 = np.sum(arr2)
print(Sum1)
# Out:
# 9

# %%
Sqrt = (np).sqrt(arr2)
print(Sqrt)
# Out:
# [[1.41421356 1.73205081]
#  [1.         1.73205081]]

# %%
Trans_arr = arr1.T
print(Trans_arr)
# Out:
# [[5 6]
#  [4 4]]

# %%
import numpy as np
a=np.array(([2,4,6],[8,10,12]),dtype=float)
print(a)
# Out:
# [[ 2.  4.  6.]
#  [ 8. 10. 12.]]

# %%
b=np.full((3,2),2,dtype=complex)
print(b)
# Out:
# [[2.+0.j 2.+0.j]
#  [2.+0.j 2.+0.j]
#  [2.+0.j 2.+0.j]]

# %%
c=np.array(([4,5,6,8],[8,9,5,5],[4,3,2,1]))
print(c)
# Out:
# [[4 5 6 8]
#  [8 9 5 5]
#  [4 3 2 1]]

# %%
d=c.reshape(4,3)
print(d)
# Out:
# [[4 5 6]
#  [8 8 9]
#  [5 5 4]
#  [3 2 1]]

# %%
e=c.flatten()
print(e)
# Out:
# [4 5 6 8 8 9 5 5 4 3 2 1]

# %%
import numpy as np
a=np.array([[1,4,6],[2,3,7]])
b=np.array([[2,4,2],[1,8,9]])
c=np.vstack((a,b))
print(c)
# Out:
# [[1 4 6]
#  [2 3 7]
#  [2 4 2]
#  [1 8 9]]

# %%
d=np.hstack((a,b))
print(d)
# Out:
# [[1 4 6 2 4 2]
#  [2 3 7 1 8 9]]

# %%
np.column_stack((a, b))
# Out:
# array([[1, 4, 6, 2, 4, 2],
#        [2, 3, 7, 1, 8, 9]])

# %%
e=np.concatenate((a,b),0)
print(e)
e=np.concatenate((a,b),1)
print(e)
# Out:
# [[1 4 6]
#  [2 3 7]
#  [2 4 2]
#  [1 8 9]]
# [[1 4 6 2 4 2]
#  [2 3 7 1 8 9]]

# %%
today=np.datetime64('today','Y')
print(today)
# Out:
# 2025

# %%
today=np.datetime64('today','M')
print(today)
# Out:
# 2025-05

# %%
today=np.datetime64('today','D')
print(today)
# Out:
# 2025-05-22

# %%
dates=np.arange('2025-11','2025-12',dtype='datetime64[D]')
print(dates)
# Out:
# ['2025-11-01' '2025-11-02' '2025-11-03' '2025-11-04' '2025-11-05'
#  '2025-11-06' '2025-11-07' '2025-11-08' '2025-11-09' '2025-11-10'
#  '2025-11-11' '2025-11-12' '2025-11-13' '2025-11-14' '2025-11-15'
#  '2025-11-16' '2025-11-17' '2025-11-18' '2025-11-19' '2025-11-20'
#  '2025-11-21' '2025-11-22' '2025-11-23' '2025-11-24' '2025-11-25'
#  '2025-11-26' '2025-11-27' '2025-11-28' '2025-11-29' '2025-11-30']

# %%
dur = np.datetime64('2025-06-19') - np.datetime64('2025-05-19')
print("No. of weeks:", np.timedelta64(dur, 'W'))
print("No. of Days:", np.timedelta64(dur, 'D'))
# Out:
# No. of weeks: 4 weeks
# No. of Days: 31 days

# %%
a = np.array(['2003-11-15', '2028-11-15', '2020-11-15','2025-11-15','2026-11-15'], dtype='datetime64')
sort=np.sort(a)
print(sort)
# Out:
# ['2003-11-15' '2020-11-15' '2025-11-15' '2026-11-15' '2028-11-15']

# %%
import numpy as np
import matplotlib.pyplot as plt
y=np.array([3,8,1,10])
plt.plot(y,linestyle='dotted',color='r',marker='*')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([3,8,1,10])
y=np.array([6,2,7,11])
plt.plot(x,linestyle='dotted',color='blue',marker='D')
plt.plot(y,linestyle='dashed',color='brown',marker='*')
plt.show()
